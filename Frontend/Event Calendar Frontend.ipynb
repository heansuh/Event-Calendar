# %%
import requests

# Airtable API credentials
API_KEY = 'pat0djiygzmoN0eHS.62e26109c98fbf97d5dd0f06736199be1658d6796a6fb7a6c586ab26b478c419'
BASE_ID = 'appDjjldOEi4s14Os'
TABLE_NAME = 'tblm5jYMfCQiEegHU'

# Airtable API endpoint
url = f'https://api.airtable.com/v0/{BASE_ID}/{TABLE_NAME}'

# Headers for authorization
headers = {
    'Authorization': f'Bearer {API_KEY}',
}

# Sending the GET request to fetch records
response = requests.get(url, headers=headers)

# Check the response status
if response.status_code == 200:
    # Print the response from Airtable
    data = response.json()
    print("Data retrieved successfully:")
    for record in data['records']:
        print(record['fields'])
else:
    print(f"Failed to retrieve records: {response.status_code}", response.text)
# Out:
# Data retrieved successfully:
# {'Field 1': 8, 'Date': '2024-09-24', 'Time': '10:00', 'Event': 'Thomas Manns „Der Zauberberg“. Fiebertraum und Höhenrausch', 'Category': 'Ausstellungen', 'Source': 'https://www.unser-luebeck.de/veranstaltungskalender/', 'Location': 'St. Annen-Museum'}
# {'Field 1': 2, 'Date': '2024-09-19', 'Time': '19:30', 'Event': 'Himmlische Zeiten - Generalprobe', 'Category': 'Theater', 'Source': 'https://www.unser-luebeck.de/veranstaltungskalender/', 'Location': 'Theaterschiff'}
# {'Field 1': 0, 'Date': '2024-09-19', 'Time': '16:00', 'Event': 'Wolfhager Figurentheater: Der Grüffelo', 'Category': 'Theater', 'Source': 'https://www.unser-luebeck.de/veranstaltungskalender/', 'Location': 'Theaterzelt Boltzplatz am Brink'}
# {'Field 1': 7, 'Date': '2024-09-20', 'Time': '20:15', 'Event': 'Lutz Krajenski feat. MOORE', 'Category': 'Musik', 'Source': 'https://www.unser-luebeck.de/veranstaltungskalender/', 'Location': 'CVJM Lübeck'}
# ...

# %%
import datetime
import os.path

from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# If modifying these scopes, delete the file token.json.
SCOPES = ["https://www.googleapis.com/auth/calendar.readonly"]


def main():
  """Shows basic usage of the Google Calendar API.
  Prints the start and name of the next 10 events on the user's calendar.
  """
  creds = None
  # The file token.json stores the user's access and refresh tokens, and is
  # created automatically when the authorization flow completes for the first
  # time.
  if os.path.exists("token.json"):
    creds = Credentials.from_authorized_user_file("token.json", SCOPES)
  # If there are no (valid) credentials available, let the user log in.
  if not creds or not creds.valid:
    if creds and creds.expired and creds.refresh_token:
      creds.refresh(Request())
    else:
      flow = InstalledAppFlow.from_client_secrets_file(
          "credentials.json", SCOPES
      )
      creds = flow.run_local_server(port=0)
    # Save the credentials for the next run
    with open("token.json", "w") as token:
      token.write(creds.to_json())

  try:
    service = build("calendar", "v3", credentials=creds)

    # Call the Calendar API
    now = datetime.datetime.utcnow().isoformat() + "Z"  # 'Z' indicates UTC time
    print("Getting the upcoming 10 events")
    events_result = (
        service.events()
        .list(
            calendarId="primary",
            timeMin=now,
            maxResults=10,
            singleEvents=True,
            orderBy="startTime",
        )
        .execute()
    )
    events = events_result.get("items", [])

    if not events:
      print("No upcoming events found.")
      return

    # Prints the start and name of the next 10 events
    for event in events:
      start = event["start"].get("dateTime", event["start"].get("date"))
      print(start, event["summary"])

  except HttpError as error:
    print(f"An error occurred: {error}")


if __name__ == "__main__":
  main()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 70
#      66     print(f"An error occurred: {error}")
#      69 if __name__ == "__main__":
# ---> 70   main()
#
# Cell In[2], line 29, in main()
#      27   creds.refresh(Request())
#      28 else:
# ---> 29   flow = InstalledAppFlow.from_client_secrets_file(
#      30       "credentials.json", SCOPES
#      31   )
#      32   creds = flow.run_local_server(port=0)
#      33 # Save the credentials for the next run
#
# File c:\Users\heans\AppData\Local\Programs\Python\Python312\Lib\site-packages\google_auth_oauthlib\flow.py:198, in Flow.from_client_secrets_file(cls, client_secrets_file, scopes, **kwargs)
#     183 @classmethod
#     184 def from_client_secrets_file(cls, client_secrets_file, scopes, **kwargs):
#     185     """Creates a :class:`Flow` instance from a Google client secrets file.
#     186
# ...

# %%
import requests

# Replace with your access token and calendar ID
access_token = 'your_access_token'
calendar_id = 'your_calendar_id'

event = {
  'summary': 'New Event',
  'start': {
    'dateTime': '2023-12-14T09:00:00+01:00',
    'timeZone': 'Europe/Berlin'
  },
  'end': {
    'dateTime': '2023-12-14T10:00:00+01:00',
    'timeZone': 'Europe/Berlin'
  }
}

headers = {'Authorization': f'Bearer {access_token}'}
response = requests.post(f'https://www.googleapis.com/calendar/v3/calendars/{calendar_id}/events', headers=headers, json=event)

if response.status_code == 200:
  print('Event added successfully')
else:
  print('Error adding event:', response.text)
